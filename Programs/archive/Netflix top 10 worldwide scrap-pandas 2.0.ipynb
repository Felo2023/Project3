# %% [markdown]
# # Netflix worldwide top 10 scrap

# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
import pandas as pd
import time

# %%
# Set up Splinter
browser = Browser('chrome')

# %%
# Visit the Mars Facts site
url = 'https://www.netflix.com/tudum/top10/es'
browser.visit(url)

# %%
all_tables=[]

for i in range(115):
    current_url=browser.url
    print(current_url)
    # Find the table
    html = browser.html
    html_soup = soup(html, 'html.parser')
    table = html_soup.find('table', class_='table-fixed')

    # Store the table
    data=table.find('tbody')
    objects = data.find_all('tr')
    table1=[]

    # Loop through the rows
    for object_ in objects:
        row=[]
        #row_heading = row.find('th').text
        object_data = object_.find_all('td')
        for cell in object_data:
            data1=cell.text
            row.append(data1)
        table1.append(row)
    if len(row)<5:
        headers=['N°','movie','week @ Top 10', 'hours seen']
    else:
        headers=['N°','movie','week @ Top 10', 'hours seen', 'duration','views']
    df=pd.DataFrame(table1,columns=headers)
    all_tables.append(df)
    browser.find_by_xpath('/html/body/div[1]/div/main/section[2]/div/div[3]/div/div/button[1]').click()
    time.sleep(1)
# Out:
# https://www.netflix.com/tudum/top10/es
# https://www.netflix.com/tudum/top10/es?week=2023-09-10
# https://www.netflix.com/tudum/top10/es?week=2023-09-03
# https://www.netflix.com/tudum/top10/es?week=2023-08-27
# https://www.netflix.com/tudum/top10/es?week=2023-08-20
# https://www.netflix.com/tudum/top10/es?week=2023-08-13
# https://www.netflix.com/tudum/top10/es?week=2023-08-06
# https://www.netflix.com/tudum/top10/es?week=2023-07-30
# https://www.netflix.com/tudum/top10/es?week=2023-07-23
# https://www.netflix.com/tudum/top10/es?week=2023-07-16
# https://www.netflix.com/tudum/top10/es?week=2023-07-09
# https://www.netflix.com/tudum/top10/es?week=2023-07-02
# https://www.netflix.com/tudum/top10/es?week=2023-06-25
# https://www.netflix.com/tudum/top10/es?week=2023-06-18
# https://www.netflix.com/tudum/top10/es?week=2023-06-11
# https://www.netflix.com/tudum/top10/es?week=2023-06-04
# https://www.netflix.com/tudum/top10/es?week=2023-05-28
# https://www.netflix.com/tudum/top10/es?week=2023-05-21
# https://www.netflix.com/tudum/top10/es?week=2023-05-14
# https://www.netflix.com/tudum/top10/es?week=2023-05-07
# https://www.netflix.com/tudum/top10/es?week=2023-04-30
# https://www.netflix.com/tudum/top10/es?week=2023-04-23
# https://www.netflix.com/tudum/top10/es?week=2023-04-16
# https://www.netflix.com/tudum/top10/es?week=2023-04-09
# https://www.netflix.com/tudum/top10/es?week=2023-04-02
# https://www.netflix.com/tudum/top10/es?week=2023-03-26
# https://www.netflix.com/tudum/top10/es?week=2023-03-19
# https://www.netflix.com/tudum/top10/es?week=2023-03-12
# https://www.netflix.com/tudum/top10/es?week=2023-03-05
# https://www.netflix.com/tudum/top10/es?week=2023-02-26
# https://www.netflix.com/tudum/top10/es?week=2023-02-19
# https://www.netflix.com/tudum/top10/es?week=2022-03-13
# https://www.netflix.com/tudum/top10/es?week=2022-03-06
# https://www.netflix.com/tudum/top10/es?week=2022-02-27
# https://www.netflix.com/tudum/top10/es?week=2022-02-20
# https://www.netflix.com/tudum/top10/es?week=2022-02-13
# https://www.netflix.com/tudum/top10/es?week=2022-02-06
# https://www.netflix.com/tudum/top10/es?week=2022-01-30
# https://www.netflix.com/tudum/top10/es?week=2022-01-23
# https://www.netflix.com/tudum/top10/es?week=2022-01-16
# https://www.netflix.com/tudum/top10/es?week=2022-01-09
# https://www.netflix.com/tudum/top10/es?week=2022-01-02
# https://www.netflix.com/tudum/top10/es?week=2021-12-26
# https://www.netflix.com/tudum/top10/es?week=2021-12-19
# https://www.netflix.com/tudum/top10/es?week=2021-12-12
# https://www.netflix.com/tudum/top10/es?week=2021-12-05
# https://www.netflix.com/tudum/top10/es?week=2021-11-28
# https://www.netflix.com/tudum/top10/es?week=2021-11-21
# https://www.netflix.com/tudum/top10/es?week=2021-11-14
# https://www.netflix.com/tudum/top10/es?week=2021-11-07
# https://www.netflix.com/tudum/top10/es?week=2021-10-31
# https://www.netflix.com/tudum/top10/es?week=2021-10-24
# https://www.netflix.com/tudum/top10/es?week=2021-10-17
# https://www.netflix.com/tudum/top10/es?week=2021-10-10
# https://www.netflix.com/tudum/top10/es?week=2021-10-03
# https://www.netflix.com/tudum/top10/es?week=2021-09-26
# https://www.netflix.com/tudum/top10/es?week=2021-09-19
# https://www.netflix.com/tudum/top10/es?week=2021-09-12
# https://www.netflix.com/tudum/top10/es?week=2021-09-05
# https://www.netflix.com/tudum/top10/es?week=2021-08-29
# https://www.netflix.com/tudum/top10/es?week=2021-08-22
# https://www.netflix.com/tudum/top10/es?week=2021-08-15
# https://www.netflix.com/tudum/top10/es?week=2021-08-08
# https://www.netflix.com/tudum/top10/es?week=2021-08-01
# https://www.netflix.com/tudum/top10/es?week=2021-07-25
# https://www.netflix.com/tudum/top10/es?week=2021-07-18
# https://www.netflix.com/tudum/top10/es?week=2021-07-11

# %%
len(all_tables)
# Out:
# 115

# %%
all_tables[14]
# Out:
#    N°                         movie week @ Top 10  hours seen
# 0   1                       Intriga             2  13.890.000
# 1   2                       Tirador             3  12.770.000
# 2   3                    Sin escape             1   9.570.000
# 3   4                      La madre             5   8.360.000
# 4   5            Un jefe en pañales             7   8.320.000
# 5   6  ¿Quién *&$%! son los Miller?             2   7.720.000
# 6   7      Angry Birds: La película             1   5.720.000
# 7   8           Hombres de negocios             1   5.390.000
# 8   9              Son como niños 2             1   5.230.000
# 9  10            En nombre del amor             2   4.950.000

# %%
i=0
for table in all_tables: 
    table.to_csv(f'../webscrapping/Netflix_{i}')
    i=i+1

# %%
# Quit the browsing session
browser.quit()
